# %% [markdown]
# ## Introduction to Python and Programming

# %% [markdown]
# ## What is Programming?
#
# Programming is the process of giving instructions to a computer to perform
# specific tasks. It involves writing code in a programming language that the
# computer can understand and execute

# %% [markdown]
# Why Python?
# 1. Python is a high-level, interpreted programming language known for its
# simplicity and readability.
# It is widely used in:
# 2. Web Development (Django, Flask)
# 3. Data Science and Machine Learning (Pandas, NumPy, TensorFlow)
# 4. Automation and Scripting
# 5. Game Development (Pygame)
# 6. Python has a large community and extensive libraries, making it
# beginner-friendly

# %% [markdown]
# ## Setting Up Python and IDEs

# %% [markdown]
# ## Installing Python
# ## 1. Download Python:
#
#    1.Visit the official Python website: python.org.
#    2.Download the latest version for your operating system (Windows, macOS,or Linux).
#   ## 3.Install Python:
#    1. Run the installer and ensure you check the box to Add Python to PATH (important for running Python from the command line).
#   ## 4. Verify Installation:
#    1. Open a terminal or command prompt and type:
#                python --version # run this
#    1. This should display the installed Python version (e.g.,
# ## Choosing an IDE
# 1. What is an IDE?
# 2. An Integrated Development Environment (IDE) is a software application
# that provides tools for writing, testing, and debugging code.
# 3. Popular Python IDEs:
# 4. VS Code: Lightweight, customizable, and supports extensions for Python.
# (We will use this one as our primary IDE)
# 5. PyCharm: Powerful IDE with advanced features for professional
# developers.
# 6. Jupyter Notebook: Great for data science and interactive coding.
# 7. IDLE: Comes pre-installed with Python; good for beginners.

# %% [markdown]
# ## Writing Our First Python Program

# %% [markdown]
# ## The "Hello, World!" Program
#
# 1. Open a folder in your VS code and type the following code in a new file
# named
# hello.py :
# print("Hello, World!")le

# %%
 print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# 1. Make sure to save the file with a .py extension (e.g., hello.py ).
# 2. Run the program:
#    1. Use the run button at the top of your IDE or alternatively type this in your VS Code integrated terminal:
#       python hello.py
#    1. Output:
#       Hello, World! ## as you can see from the above we ran it and we can see the output

# %% [markdown]
# ## Key Takeaways :
# 1. print() is a built-in function used to display output.
# 2. Python code is executed line by line

# %% [markdown]
# @@ Understanding Python Syntax and Basics
#
# ## python Syntax Rules
#
# ## 1. Indentation
#    1. Python uses indentation (spaces or tabs) to define blocks of code.
#
#     2.Example:

# %%
if 5 > 2:
print("Five is greater than two!")
# Spaces before print are called indentation
# Out:
#   Cell In[14], line 2
#     print("Five is greater than two!")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# ## 2. Whitespace:
# Python is sensitive to whitespace. Ensure consistent indentation to avoid errors. Ideally, use 4 spaces for indentation.
# ## 3. Statements:
# 1. Each line of code is a statement. You can write multiple statements on on line using a semicolon ( ; ), but this is not recommend
#
# ## 4. Comments:
#   1. Use # for single-line comments.
#   2. Use ''' or """ for multi-line comments.
#   3. Example:

# %%
# This is a single-line comment
'''
This is a
multi-line comment
'''
# Out:
# '\nThis is a\nmulti-line comment\n'

# %% [markdown]
# ## Notes from Myside

# %%
1. Python is a versatile and beginner-friendly programming language.
2. Setting up Python and choosing the right IDE is the first step to writingcode.
